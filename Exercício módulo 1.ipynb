# %%
numero1 = float(input("Digite um numero: "))
numero2 = float(input("Digite outro numero: "))

soma = numero1 + numero2

subitração = numero1 - numero2

multiplicação = numero1 * numero2

divisão = numero1 / numero2

print("A soma dos numeros é: ", soma)

print("A subtração dos numeros é: ", subitração)

print("A multiplicação dos numeros é: ", multiplicação)

print("A divisão dos numeros é: ", divisão)
# Out:
# Digite um numero: 10
# Digite outro numero: 40
# A soma dos numeros é:  50.0
# A subtração dos numeros é:  -30.0
# A multiplicação dos numeros é:  400.0
# A divisão dos numeros é:  0.25
